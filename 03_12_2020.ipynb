# %% [markdown]
# <a href="https://colab.research.google.com/github/yaelfierro/cyp_2021/blob/main/03_12_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo 1
for i in[1,2,3,5]:
  print(f"el elemento: {i}")
# Out:
# el elemento: 1
# el elemento: 2
# el elemento: 3
# el elemento: 5

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
  print(f"el elemento: {i}")

# %%
#Ejemplo 2

coleccion={"Mario":20, "Mariana":19, "Jessica":14, "Luis":18}
for i in coleccion:
  print(f"Elemento: {i}")

# %%
coleccion={"Mario":20, "Mariana":19, "Jessica":14, "Luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")

# %%
coleccion={"Mario":20, "Mariana":19, "Jessica":14, "Luis":18}
for i in coleccion:
  print(f"{i}->{coleccion[i]}")

# %%
coleccion={"Mario":20, "Mariana":19, "Jessica":14, "Luis":18}

for clave, valor in coleccion.items():
  print(f"{clave} ->{valor}")

# %%
#Ejemplo 3

email=False
for i in"ariel@unam.com.mx":
  if(i =="@"):
    email=True
if email== True:
  print("El email es correcto")

else:
  print("El email no es correcto")

# %%
email=False
miEmail=input("Introduce tu correo electronico")

for i in miEmail:

  if(i =="@"):
    email=True
    
if email== True:
  print("El email es correcto")

else:
  print("El email no es correcto")

# %%
#For-Range

for i in range (5):
  print("hola")

# %%
for i in range (5):
  print(i)

# %%
#While ejemplos

#Ejemplo 1

i=1
while i<= 10:
    print("Ejecución"+ str(i))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# Ejecución1
# ...

# %%
i=1

while i <=10:
  print("ejecución"+str(i))

  i=i+1 #contador, es decir, incremento de uno en la variable

# %%
edad=int(input("introduce tu edad:"))
while edad <0:
  print("Has introducido una edad negativa, inténtalo de nuevo")
  edad=int(input("Introduce tu edad:"))
print("Gracias por participar. Puede pasar")
print("Edad del aspirante"+str (edad))

# %%
edad=int(input("introduce tu edad:"))
while edad <10 or edad <100:
  print("Has introducido una edad negativa, inténtalo de nuevo")
  edad=int(input("Introduce tu edad:"))
print("Gracias por participar. Puede pasar")
print("Edad del aspirante"+str (edad))
